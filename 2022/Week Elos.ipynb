# %%
import pandas as pd

import statbotics

sb = statbotics.Statbotics()

# %%
team_events_1 = sb.get_team_events(year=2022, week=1, fields=["team", "team_name", "event", "elo_start", "elo_end", "opr_auto", "opr_teleop", "opr_endgame", "opr_no_fouls", "wins", "losses", "ties"], metric="elo_end", limit=50)
pd.DataFrame(team_events_1)  # .to_markdown(index=False))
# Out:
#     team                 team_name      event  elo_start  elo_end  opr_auto  \
# 0   1678           Citrus Circuits   2022caph       1798     2001     15.90
# 1    148             Robowranglers  2022txwac       1817     1955     15.08
# 2   2910           Jack in the Bot  2022wasno       1828     1953     16.65
# 3   1690                     Orbit  2022isde1       1796     1947     12.50
# 4    179     Children of the Swamp   2022flwp       1773     1874     10.99
# 5     27                 Team RUSH  2022miket       1739     1853     13.05
# 6   3310       Black Hawk Robotics  2022txwac       1702     1847     13.60
# 7   2200               MMRambotics  2022on306       1767     1840     13.64
# 8   4414                  HighTide   2022caph       1694     1832     17.02
# 9   2168          Aluminum Falcons   2022flwp       1778     1817     10.39
# 10  3357                    COMETS  2022mifor       1695     1812     10.97
# ...

# %%
team_events_2 = sb.get_team_events(year=2022, week=2, fields=["team", "team_name", "event", "elo_start", "elo_end", "opr_auto", "opr_teleop", "opr_endgame", "opr_no_fouls", "wins", "losses", "ties"], metric="elo_end", limit=50)
pd.DataFrame(team_events_2)  # .to_markdown(index=False))
# Out:
#     team                            team_name      event  elo_start  elo_end  \
# 0    179                Children of the Swamp   2022flor       1874     1930
# 1   4414                             HighTide   2022cave       1832     1891
# 2    118                            Robonauts  2022txcha       1758     1884
# 3   3538                          RoboJackets  2022miroc       1784     1884
# 4    987                          HIGHROLLERS   2022caoc       1773     1864
# 5    176                            Aces High  2022ctwat       1739     1855
# 6   2046                           Bear Metal  2022orwil       1833     1837
# 7    359                        Hawaiian Kids   2022cave       1765     1832
# 8   1619                  Up-A-Creek Robotics   2022okok       1760     1832
# 9   3476                          Code Orange   2022caoc       1657     1829
# 10  4635                PrepaTec - Botbusters   2022mxmo       1678     1829
# ...

# %%
team_events_3 = sb.get_team_events(year=2022, week=3, fields=["team", "team_name", "event", "elo_start", "elo_end", "opr_auto", "opr_teleop", "opr_endgame", "opr_no_fouls", "wins", "losses", "ties"], metric="elo_end", limit=50)
team_events_3_df = pd.DataFrame(team_events_3)
team_events_3_df  # .to_markdown(index=False))
# Out:
#     team                         team_name      event  elo_start  elo_end  \
# 0   1690                             Orbit  2022isde3       1947     2122
# 1   2910                   Jack in the Bot  2022wayak       1953     2031
# 2    176                         Aces High  2022mawne       1855     1959
# 3    125                           NUTRONs  2022marea       1730     1919
# 4   3357                            COMETS  2022mimus       1812     1913
# 5     27                         Team RUSH   2022paca       1853     1905
# 6   2363                      Triple Helix  2022va320       1869     1898
# 7   2075                   Enigma Robotics  2022mimus       1756     1876
# 8   5813                          Morpheus  2022marea       1705     1870
# 9   2363                      Triple Helix  2022va319       1752     1869
# 10   870               TEAM  R. I. C. E.     2022nyli       1727     1859
# 11  6800                             Valor  2022txaus       1728     1848
# ...

# %%
team_events_4 = sb.get_team_events(year=2022, week=4, fields=["team", "team_name", "event", "elo_start", "elo_end", "opr_auto", "opr_teleop", "opr_endgame", "opr_no_fouls", "wins", "losses", "ties"], metric="elo_end", limit=50)
team_events_4_df = pd.DataFrame(team_events_4)
team_events_4_df  # .to_markdown(index=False))
# Out:
#     team                 team_name      event  elo_start  elo_end  opr_auto  \
# 0   1690                     Orbit  2022iscmp       2122     2091     18.17
# 1    254          The Cheesy Poofs   2022cada       1865     2083     16.89
# 2   1678           Citrus Circuits   2022cada       2001     2033     12.30
# 3    148             Robowranglers  2022txirv       1955     2025     16.62
# 4   3310       Black Hawk Robotics  2022txirv       1847     1974     14.47
# 5   1323          MadTown Robotics   2022camb       1842     1958     14.72
# 6    973                  Greybots   2022cada       1801     1955     13.42
# 7   1771   North Gwinnett Robotics  2022gacar       1825     1954     18.45
# 8    870       TEAM  R. I. C. E.    2022nyli2       1859     1944      8.90
# 9   3538               RoboJackets  2022misal       1884     1937      8.71
# 10  1577                 Steampunk  2022iscmp       1798     1931     16.79
# ...

# %%
week_4_top_25_df = team_events_4_df.append(team_events_3_df[(team_events_3_df.event == "2022isde3") | (team_events_3_df.event == "2022nyli")])
week_4_top_25_df_out = week_4_top_25_df[week_4_top_25_df.wins > 0].sort_values(by=["elo_end"], ascending=False).reset_index().head(40)[["team", "team_name", "event", "elo_end", "opr_no_fouls", "wins", "losses", "ties"]]
week_4_top_25_df_out  # .to_markdown(index=False))
# Out:
#     team                team_name      event  elo_end  opr_no_fouls  wins  \
# 0   1690                    Orbit  2022isde3     2122         77.00    17
# 1   1690                    Orbit  2022iscmp     2091         71.23    17
# 2    254         The Cheesy Poofs   2022cada     2083         80.66    16
# 3   1678          Citrus Circuits   2022cada     2033         63.29    16
# 4    148            Robowranglers  2022txirv     2025         63.46    16
# 5   3310      Black Hawk Robotics  2022txirv     1974         65.64    17
# 6   1323         MadTown Robotics   2022camb     1958         70.86    18
# 7    973                 Greybots   2022cada     1955         60.04    13
# 8   1771  North Gwinnett Robotics  2022gacar     1954         68.68    17
# 9    870      TEAM  R. I. C. E.    2022nyli2     1944         53.88    16
# 10  3538              RoboJackets  2022misal     1937         52.67    18
# 11  1577                Steampunk  2022iscmp     1931         70.90    17
# ...

# %%
team_events_5 = sb.get_team_events(year=2022, week=5, fields=["team", "team_name", "event", "elo_start", "elo_end", "opr_auto", "opr_teleop", "opr_endgame", "opr_no_fouls", "wins", "losses", "ties"], metric="elo_end", limit=50)
team_events_5_df = pd.DataFrame(team_events_5)
team_events_5_df  # .to_markdown(index=False))
# Out:
#     team                         team_name      event  elo_start  elo_end  \
# 0   1323                  MadTown Robotics   2022cafr       1958     2144
# 1   2910                   Jack in the Bot  2022wabon       2031     2077
# 2    973                          Greybots   2022cafr       1955     2050
# 3    179             Children of the Swamp   2022lake       1930     1963
# 4     27                         Team RUSH  2022mitry       1905     1952
# 5   2046                        Bear Metal  2022wabon       1865     1952
# 6    987                       HIGHROLLERS   2022nvlv       1864     1925
# 7   2767                      Stryke Force  2022milak       1813     1904
# 8   4635             PrepaTec - Botbusters   2022arli       1918     1902
# 9   3476                       Code Orange   2022cala       1829     1896
# 10  5940                             BREAD   2022cafr       1787     1895
# 11  3357                            COMETS  2022miken       1913     1891
# ...

# %%
team_events_6 = sb.get_team_events(year=2022, week=6, fields=["team", "team_name", "event", "elo_start", "elo_end", "opr_auto", "opr_teleop", "opr_endgame", "opr_no_fouls", "wins", "losses", "ties"], metric="elo_end", limit=50)
team_events_6_df = pd.DataFrame(team_events_6)
team_events_6_df  # .to_markdown(index=False))
# Out:
#     team                team_name       event  elo_start  elo_end  opr_auto  \
# 0    254         The Cheesy Poofs    2022casj       2083     2101     18.66
# 1   2910          Jack in the Bot   2022pncmp       2077     2088     13.89
# 2   1678          Citrus Circuits    2022casj       2033     2067     15.30
# 3   6800                    Valor  2022txcmp1       1848     1982     16.53
# 4   6800                    Valor   2022txcmp       1848     1982     12.11
# 5   5895          Peddie Robotics   2022mrcmp       1834     1972     18.34
# 6    148            Robowranglers   2022txcmp       2025     1970     16.62
# 7    148            Robowranglers  2022txcmp1       2025     1969     15.40
# 8   1771  North Gwinnett Robotics   2022gacmp       1954     1965     16.02
# 9   4414                 HighTide    2022caav       1891     1949     14.93
# 10  2056              OP Robotics   2022on409       1896     1949     15.22
# ...

# %%
week_6_top_25_df = team_events_6_df[team_events_6_df.event != "2022txcmp"]
week_6_top_25_df_out = week_6_top_25_df[week_6_top_25_df.wins > 0].sort_values(by=["elo_end"], ascending=False).reset_index().head(40)[["team", "team_name", "event", "elo_end", "opr_no_fouls", "wins", "losses", "ties"]]
print(week_6_top_25_df_out.to_markdown(index=False))
# Out:
# |   team | team_name               | event      |   elo_end |   opr_no_fouls |   wins |   losses |   ties |
# |-------:|:------------------------|:-----------|----------:|---------------:|-------:|---------:|-------:|
# |    254 | The Cheesy Poofs        | 2022casj   |      2101 |          73.48 |     15 |        0 |      0 |
# |   2910 | Jack in the Bot         | 2022pncmp  |      2088 |          59.69 |     17 |        2 |      0 |
# |   1678 | Citrus Circuits         | 2022casj   |      2067 |          74.3  |     15 |        0 |      0 |
# |   6800 | Valor                   | 2022txcmp1 |      1982 |          66.11 |     18 |        2 |      0 |
# |   5895 | Peddie Robotics         | 2022mrcmp  |      1972 |          56.59 |     17 |        2 |      0 |
# |    148 | Robowranglers           | 2022txcmp1 |      1969 |          52.47 |     16 |        4 |      0 |
# |   1771 | North Gwinnett Robotics | 2022gacmp  |      1965 |          56.58 |     16 |        2 |      0 |
# ...

# %%
movers = sb.get_team_years(year=2022, fields=["team", "name", "elo_start", "elo_end", "elo_diff", "winrate"], metric="elo_diff", limit=20)
movers_df = pd.DataFrame(movers)
movers_df[movers_df.elo_start < 1700]  # .to_markdown(index=False))
# Out:
#     team                     name  elo_start  elo_end  elo_diff  winrate
# 0   1771  North Gwinnett Robotics       1661     1954       293   0.9444
# 3   5813                 Morpheus       1602     1870       268   0.8919
# 4   8736           The Mechanisms       1450     1711       261   0.9167
# 5   6800                    Valor       1594     1848       254   0.9189
# 6   4635    PrepaTec - Botbusters       1678     1918       240   0.9688
# 7   2363             Triple Helix       1659     1898       239   0.9186
# 9   4206               Robo Vikes       1510     1745       235   0.8056
# 10  2135    Presentation Invasion       1491     1721       230   0.7105
# 11  7457     suPURDUEper Robotics       1676     1906       230   1.0000
# 13  5940                    BREAD       1567     1787       220   0.8947
# 15  7157                  μBotics       1481     1699       218   0.6714
# 16  3357                   COMETS       1695     1913       218   0.9595
# ...
