# %%
import pandas as pd

import statbotics

sb = statbotics.Statbotics()

# %%
team_events_1 = sb.get_team_events(year=2022, week=1, fields=["team", "team_name", "event", "elo_start", "elo_end", "opr_auto", "opr_teleop", "opr_endgame", "opr_no_fouls", "wins", "losses", "ties"], metric="elo_end", limit=30)
pd.DataFrame(team_events_1)  # .to_markdown(index=False))
# Out:
#     team              team_name      event  elo_start  elo_end  opr_auto  \
# 0   1678        Citrus Circuits   2022caph       1798     2001     15.90
# 1    148          Robowranglers  2022txwac       1817     1955     15.08
# 2   2910        Jack in the Bot  2022wasno       1828     1953     16.65
# 3   1690                  Orbit  2022isde1       1796     1947     12.41
# 4    179  Children of the Swamp   2022flwp       1773     1874     10.99
# 5     27              Team RUSH  2022miket       1739     1853     13.04
# 6   3310    Black Hawk Robotics  2022txwac       1702     1847     13.60
# 7   2200            MMRambotics  2022on306       1767     1840     13.64
# 8   4414               HighTide   2022caph       1694     1832     17.02
# 9   2168       Aluminum Falcons   2022flwp       1778     1817     10.39
# 10  3357                 COMETS  2022mifor       1695     1812     10.97
# 11  5895        Peddie Robotics  2022pahat       1652     1806     15.09
# ...

# %%
team_events_2 = sb.get_team_events(year=2022, week=2, fields=["team", "team_name", "event", "elo_start", "elo_end", "opr_auto", "opr_teleop", "opr_endgame", "opr_no_fouls", "wins", "losses", "ties"], metric="elo_end", limit=30)
print(pd.DataFrame(team_events_2).to_markdown(index=False))
# Out:
# |   team | team_name               | event     |   elo_start |   elo_end |   opr_auto |   opr_teleop |   opr_endgame |   opr_no_fouls |   wins |   losses |   ties |
# |-------:|:------------------------|:----------|------------:|----------:|-----------:|-------------:|--------------:|---------------:|-------:|---------:|-------:|
# |    179 | Children of the Swamp   | 2022flor  |        1874 |      1930 |      18.58 |        19.19 |         12.01 |          49.78 |     15 |        0 |      0 |
# |   4414 | HighTide                | 2022cave  |        1832 |      1891 |      16.56 |        30.36 |          7.2  |          54.12 |     17 |        0 |      0 |
# |    118 | Robonauts               | 2022txcha |        1758 |      1884 |      12.51 |        21.31 |         12.66 |          46.48 |     18 |        0 |      0 |
# ...

# %%
team_events_3 = sb.get_team_events(year=2022, week=3, fields=["team", "team_name", "event", "elo_start", "elo_end", "opr_auto", "opr_teleop", "opr_endgame", "opr_no_fouls", "wins", "losses", "ties"], metric="elo_end", limit=30)
print(pd.DataFrame(team_events_3).to_markdown(index=False))
# Out:
# |   team | team_name              | event     |   elo_start |   elo_end |   opr_auto |   opr_teleop |   opr_endgame |   opr_no_fouls |   wins |   losses |   ties |
# |-------:|:-----------------------|:----------|------------:|----------:|-----------:|-------------:|--------------:|---------------:|-------:|---------:|-------:|
# |   2910 | Jack in the Bot        | 2022wayak |        1953 |      2031 |      17.18 |        32.75 |          8.78 |          58.71 |     16 |        0 |      0 |
# |    176 | Aces High              | 2022mawne |        1855 |      1959 |      15    |        27.8  |         11.08 |          53.89 |     18 |        0 |      0 |
# |   1690 | Orbit                  | 2022isde3 |        1947 |      1947 |      12.41 |        33.64 |          9.05 |          55.1  |      0 |        0 |      0 |
# |    125 | NUTRONs                | 2022marea |        1730 |      1919 |      11.67 |        22.27 |         11.49 |          45.44 |     18 |        1 |      0 |
# ...

# %%
movers = sb.get_team_years(year=2022, fields=["team", "name", "elo_start", "elo_end", "elo_diff", "winrate"], metric="elo_diff", limit=10)
pd.DataFrame(movers)  # .to_markdown(index=False))

# https://www.thebluealliance.com/team/7407/2022 -> massive improvement, undefeated
# https://www.thebluealliance.com/team/3476/2022 -> regain high level of play
# https://www.thebluealliance.com/team/1771/2022 -> consistent winning, started dominating
# https://www.thebluealliance.com/team/2135/2022 -> under the radar finalist after ranking 46th in 2019
# https://www.thebluealliance.com/team/6328/2022 -> same alliance as 7407, highly competitive field
# https://www.thebluealliance.com/team/359/2022 -> rebound from 2019
# https://www.thebluealliance.com/team/5895/2022 -> consistent improvement
# Out:
#    team             name  elo_start  elo_end  elo_diff  winrate
# 0  5813         Morpheus       1602     1870       268   0.8919
# 1  6800            Valor       1594     1848       254   0.9189
# 2  2363     Triple Helix       1659     1898       239   0.9186
# 3  4206       Robo Vikes       1510     1745       235   0.8056
# 4   176        Aces High       1739     1959       220   1.0000
# 5  3357           COMETS       1695     1913       218   0.9595
# 6  7285    Sneaky Snakes       1535     1752       217   0.9688
# 7  2910  Jack in the Bot       1828     2031       203   0.9706
# 8  1678  Citrus Circuits       1798     2001       203   0.9444
# 9  4414         HighTide       1694     1891       197   0.9571
